# %%
port = 8081

# %%
# from Puppets.negative import NegativePuppet
import sys
sys.path.append('../')
from Puppets.fixation import FixationPuppet
from Puppets.tribal import TribalPuppet
from Puppets.random import RandomPuppet
from Puppets.outrage import OutragePuppet

bot = OutragePuppet(port)
# Out:
# Loaded pre-trained tokenizer at: /Users/hussam/Desktop/Projects/outrage_classifier/26k_training_data.joblib

# %%
bot.signin('ahmed')
# Out:
# Signing in...
# Sent request to call 'signin' with arguments ['ahmed']
# Response from server: {'status': 'success', 'result': {'status': 'success', 'message': 'Signed in successfully'}}
# Signed in successfully. Proceeding with next operations.

# %%
graph = bot.multiBinge(binge_depth=33, binge_restarts=5, plot='both')
# Out:
# Binge: 32
# 32 Watch: h5HTlfN5a3U
# Watched: COP APPROACHES me while mowing DESERTED HOME and tells me THIS
# Watched: PISSED NEIGHBOR TRIES TO KICK US OFF THIS BACKYARD MULCHING JOB!
# Watched: SHOTS FIRED!? VANDALS TRYING TO RUN OWNER OFF! MUNCHIE TO THE RESCUE!
# Watched: The Largest And Most Stuck Excavator I’ve Ever Recovered
# Watched: My Excavator Got Stuck In Bottomless Quicksand - My Worst Nightmare
# Watched: I’ve Never Seen A Big Rig THIS Stuck (Dangerous And Difficult Recovery)
# Watched: Bill Burr - Let It Go - 2010 - Stand-up Special
# Watched: Orny Adams ● More Than Loud - Full Comedy Special
# Watched: Gutfeld! 4/11/24 FULL HD | FOX BREAKING NEWS TRUMP April 11, 2024
# Watched: Matt Rife | Only Fans (Full Comedy Special)
# Watched: Pete Davidson: SMD
# Watched: 4 Hours Funny Moments 🌻King Of The Hill 🌻 Part 61🌻 Full Episodes 2024
# Watched: The Simpsons Season 39 Ep 2 | The Simpsons 2024 Full Episode | [NEW] NoCuts Full #1080p
# ...

# %%
import pickle as pkl
pkl.dump(graph, open('traces/outrage-multi.pkl', 'wb'))

# %%
videos = dict()
videos['small'] = 1
videos['b'] = 5
videos['c'] = 3
videos['big'] = 8
videos['e'] = 2

# get a list of keys sorted by values

# %%
high = False
sorted_keys = sorted(videos, key=videos.get, reverse=high)
sorted_keys
# Out:
# ['small', 'e', 'c', 'b', 'big']
